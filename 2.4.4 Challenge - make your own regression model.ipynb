# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sklearn import linear_model
# %matplotlib inline
pd.options.display.float_format = '{:.3f}'.format

import warnings
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Thinkful-Ed/data-201-resources/master/New_York_offenses/NEW_YORK-Offenses_Known_to_Law_Enforcement_by_City_2013%20-%2013tbl8ny.csv')
display(df.head())
# Out:
#                              Table 8  Unnamed: 1      Unnamed: 2  \
# 0                           NEW YORK         NaN             NaN
# 1  Offenses Known to Law Enforcement         NaN             NaN
# 2                      by City, 2013         NaN             NaN
# 3                               City  Population  Violent\ncrime
# 4                      Adams Village       1,861               0
#
#                                Unnamed: 3                    Unnamed: 4  \
# 0                                     NaN                           NaN
# 1                                     NaN                           NaN
# 2                                     NaN                           NaN
# 3  Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1
# 4                                       0                           NaN
#
#                     Unnamed: 5 Unnamed: 6           Unnamed: 7  \
# 0                          NaN        NaN                  NaN
# ...

# %%
df.drop(df.head(4).index, inplace=True)

# %%
df.columns = ['city', 'population', 'violent crime', 'murder', 'rape revision', 'rape legacy', 'robbery', 'aggravated assault', 'property crime', 'burglary', 'larceny theft', 'vehicle theft', 'arson']
print(df.head())
# Out:
#                        city population violent crime murder rape revision  \
# 4             Adams Village      1,861             0      0           NaN
# 5  Addison Town and Village      2,577             3      0           NaN
# 6             Akron Village      2,846             3      0           NaN
# 7                    Albany     97,956           791      8           NaN
# 8            Albion Village      6,388            23      0           NaN
#
#   rape legacy robbery aggravated assault property crime burglary  \
# 4           0       0                  0             12        2
# 5           0       0                  3             24        3
# 6           0       0                  3             16        1
# 7          30     227                526          4,090      705
# 8           3       4                 16            223       53
#
#   larceny theft vehicle theft arson
# 4            10             0     0
# 5            20             1     0
# ...

# %%
df.describe()
# Out:
#                        city population violent crime murder  rape revision  \
# count                   351        348           348    348          0.000
# unique                  351        347            82     14          0.000
# top     Blooming Grove Town      9,517             0      0            nan
# freq                      1          2            51    299            nan
#
#        rape legacy robbery aggravated assault property crime burglary  \
# count          348     348                348            348      348
# unique          26      51                 69            239      124
# top              0       0                  0              0        0
# freq           204     139                 66              6       21
#
#        larceny theft vehicle theft arson
# count            348           348   187
# unique           232            51    13
# top                0             0     0
# freq               7            93   133

# %%
df = df.drop('rape revision', axis=1)

# %%
df = df.dropna()
column_names = df.columns

for column in column_names:
    df[column] = df[column].astype('str').str.replace(',', '')

regr = linear_model.LinearRegression()
Y = df['property crime'].astype('float')
X = df[['burglary','larceny theft']].astype('float')
Y = Y.values.reshape(-1, 1)
regr.fit(X, Y)

print('\nCoefficients: \n', regr.coef_)
print('\nIntercept: \n', regr.intercept_)
print('\nR-squared:')
print(regr.score(X, Y))
# Out:
# Coefficients:
#  [[1.21623383 1.0051162 ]]
#
# Intercept:
#  [-1.48352736]
#
# R-squared:
# 0.9998090299265471

# %%
print(X)
# Out:
#      burglary  larceny theft  vehicle theft
# 4       2.000         10.000          0.000
# 5       3.000         20.000          1.000
# 6       1.000         15.000          0.000
# 10      0.000         10.000          0.000
# 11    204.000       1882.000         32.000
# 12     16.000        188.000          6.000
# 13     99.000        291.000         15.000
# 14      3.000         35.000          1.000
# 15      4.000         28.000          1.000
# 16      0.000          2.000          0.000
# 17      0.000          4.000          1.000
# 20     10.000         77.000          1.000
# 21     16.000         78.000          0.000
# 23     32.000        157.000          2.000
# 27      2.000         12.000          0.000
# 29      2.000          2.000          0.000
# 30      4.000         20.000          0.000
# 31      6.000         14.000          0.000
# 32      9.000         20.000          2.000
# 33      3.000         10.000          0.000
# ...

# %%
print(Y)
# Out:
# [[1.2000e+01]
#  [2.4000e+01]
#  [1.6000e+01]
#  [1.0000e+01]
#  [2.1180e+03]
#  [2.1000e+02]
#  [4.0500e+02]
#  [3.9000e+01]
#  [3.3000e+01]
#  [2.0000e+00]
#  [5.0000e+00]
#  [8.8000e+01]
#  [9.4000e+01]
#  [1.9100e+02]
#  [1.4000e+01]
#  [4.0000e+00]
#  [2.4000e+01]
#  [2.0000e+01]
#  [3.1000e+01]
#  [1.3000e+01]
#  [1.1000e+01]
#  [4.7000e+01]
#  [1.0000e+01]
#  [4.6000e+01]
#  [3.4800e+02]
#  [1.2000e+01]
#  [2.0000e+00]
#  [1.9800e+02]
#  [8.0000e+00]
#  [4.0000e+00]
#  [5.3000e+01]
#  [3.2000e+01]
#  [2.6890e+03]
#  [2.1800e+02]
#  [8.6000e+01]
#  [1.9900e+03]
#  [4.1600e+02]
#  [3.9800e+02]
#  [8.1000e+01]
#  [1.5200e+02]
#  [3.1000e+02]
#  [1.4000e+01]
#  [7.1500e+02]
#  [8.0000e+00]
#  [1.0400e+02]
#  [1.3100e+02]
#  [1.6800e+02]
#  [3.7300e+02]
#  [6.6000e+01]
#  [1.4700e+02]
#  [3.1000e+01]
#  [1.7300e+02]
#  [8.9000e+01]
#  [1.0000e+00]
#  [3.1300e+02]
#  [2.7600e+02]
#  [7.2000e+01]
#  [3.2000e+01]
#  [9.3300e+02]
#  [1.6000e+01]
#  [4.6300e+02]
#  [3.4600e+02]
# ...
